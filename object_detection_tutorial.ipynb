# %% [markdown]
# # Object Detection Demo
# Welcome to the object detection inference walkthrough!  This notebook will walk you step by step through the process of using a pre-trained model to detect objects in an image. Make sure to follow the [installation instructions](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/installation.md) before you start.

# %% [markdown]
# # Imports

# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile
import cv2

import matplotlib.pyplot as plt


from collections import defaultdict
from io import StringIO

from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
from object_detection.utils import ops as utils_ops

if tf.__version__ < '1.4.0':
  raise ImportError('Please upgrade your tensorflow installation to v1.4.* or later!')

# %% [markdown]
# ## Env setup

# %%
# This is needed to display the images.
# %matplotlib auto
# Out:
# Using matplotlib backend: TkAgg

# %% [markdown]
# ## Object detection imports
# Here are the imports from the object detection module.

# %%
from utils import label_map_util

from utils import visualization_utils as vis_util
# Out:
# utils/visualization_utils.py:25: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to u'TkAgg' by the following code:
#   File "/usr/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/usr/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python2.7/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/usr/local/lib/python2.7/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python2.7/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2828, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-7c19fa3992e4>", line 2, in <module>
#     get_ipython().magic(u'matplotlib auto')
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.py", line 229, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   import matplotlib; matplotlib.use('Agg')  # pylint: disable=multiple-statements

# %% [markdown]
# # Model preparation

# %% [markdown]
# ## Variables
#
# Any model exported using the `export_inference_graph.py` tool can be loaded here simply by changing `PATH_TO_CKPT` to point to a new .pb file.
#
# By default we use an "SSD with Mobilenet" model here. See the [detection model zoo](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/detection_model_zoo.md) for a list of other models that can be run out-of-the-box with varying speeds and accuracies.

# %%
# What model to download.
#MODEL_NAME = 'ssd_mobilenet_v1_coco_2017_11_17'
#http://download.tensorflow.org/models/object_detection/ssdlite_mobilenet_v2_coco_2018_05_09.tar.gz
#MODEL_NAME = 'ssdlite_mobilenet_v2_coco_2018_05_09'
MODEL_NAME = 'ssd_inception_v2_coco_2017_11_17'
#MODEL_NAME = 'ssd_mobilenet_v2_coco_2018_03_29'
MODEL_FILE = MODEL_NAME + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'
# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = MODEL_NAME + '/frozen_inference_graph.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('data', 'mscoco_label_map.pbtxt')

NUM_CLASSES = 90

# %% [markdown]
# ## Download Model

# %%
if not os.path.isfile(MODEL_FILE):
    opener = urllib.request.URLopener()
    opener.retrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)
tar_file = tarfile.open(MODEL_FILE)
for file in tar_file.getmembers():
  file_name = os.path.basename(file.name)
  if 'frozen_inference_graph.pb' in file_name:
    tar_file.extract(file, os.getcwd())

# %% [markdown]
# ## Load a (frozen) Tensorflow model into memory.

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
  od_graph_def = tf.GraphDef()
  with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')

# %% [markdown]
# ## Loading label map
# Label maps map indices to category names, so that when our convolution network predicts `5`, we know that this corresponds to `airplane`.  Here we use internal utility functions, but anything that returns a dictionary mapping integers to appropriate string labels would be fine

# %%
label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
category_index = label_map_util.create_category_index(categories)

# %% [markdown]
# ## Helper code

# %%
def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# # Detection

# %%
# For the sake of simplicity we will use only 2 images:
# image1.jpg
# image2.jpg
# If you want to test the code with your images, just add path to the images to the TEST_IMAGE_PATHS.
PATH_TO_TEST_IMAGES_DIR = 'test_images'
TEST_IMAGE_PATHS = [ os.path.join(PATH_TO_TEST_IMAGES_DIR, 'image{}.jpg'.format(i)) for i in range(1, 3) ]

# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)

# %%
def run_inference_for_single_image(image, graph):
  with graph.as_default():
    with tf.Session() as sess:
      # Get handles to input and output tensors
      ops = tf.get_default_graph().get_operations()
      all_tensor_names = {output.name for op in ops for output in op.outputs}
      tensor_dict = {}
      for key in [
          'num_detections', 'detection_boxes', 'detection_scores',
          'detection_classes', 'detection_masks'
      ]:
       
        tensor_name = key + ':0'
        if tensor_name in all_tensor_names:
          tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
              tensor_name)
      if 'detection_masks' in tensor_dict:
        # The following processing is only for single image
        detection_boxes = tf.squeeze(tensor_dict['detection_boxes'], [0])
        detection_masks = tf.squeeze(tensor_dict['detection_masks'], [0])
        # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
        real_num_detection = tf.cast(tensor_dict['num_detections'][0], tf.int32)
        detection_boxes = tf.slice(detection_boxes, [0, 0], [real_num_detection, -1])
        detection_masks = tf.slice(detection_masks, [0, 0, 0], [real_num_detection, -1, -1])
        detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
            detection_masks, detection_boxes, image.shape[0], image.shape[1])
        detection_masks_reframed = tf.cast(
            tf.greater(detection_masks_reframed, 0.5), tf.uint8)
        # Follow the convention by adding back the batch dimension
        tensor_dict['detection_masks'] = tf.expand_dims(
            detection_masks_reframed, 0)
      image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

      # Run inference
      output_dict = sess.run(tensor_dict,
                             feed_dict={image_tensor: np.expand_dims(image, 0)})

      classes = output_dict['detection_classes']
        
      # all outputs are float32 numpy arrays, so convert types as appropriate
      output_dict['num_detections'] = int(output_dict['num_detections'][0])
      output_dict['detection_classes'] = output_dict[
          'detection_classes'][0].astype(np.uint8)
    
      output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
      output_dict['detection_scores'] = output_dict['detection_scores'][0]
      if 'detection_masks' in output_dict:
        output_dict['detection_masks'] = output_dict['detection_masks'][0]
      
            
  return output_dict

# %%
# blocks until it finds the next video to analyse
import os
import time

def wait_for_video( directory, time_limit=3600, check_interval=60 ):
    '''Return next video file to process, if not keep checking once every check_interval seconds for time_limit seconds.
    time_limit defaults to 1 hour
    check_interval defaults to 1 minute
    '''

    now = time.time()
    last_time = now + time_limit

    while time.time() <= last_time:
        print "Searching for new camera uploads"
        for root, dirs, files in os.walk(directory):
           files = [ fi for fi in files if fi.endswith(".mp4") and not fi.startswith(".")  ]
           for file in files:
                filePath = os.path.join(root, file)
               
                if not os.path.isfile(filePath + '.processed'):
                    return filePath
 
        # Wait for check interval seconds, then check again.
        time.sleep( check_interval )

    return None

#wait_for_video( "/data/videos/incoming", 3600, 1 )

# %%
def moveVideoToArchive(file):
    open(file + '.processed', 'w')

# %%
def detectPerson(output_dict, category_index):
    result = False
    classes = output_dict['detection_classes']  
    for i in range(len(classes)):
        score = output_dict['detection_scores'][i]
        label = category_index.get(classes[i])
        if (score>0.5 and label['name'] == 'person' ):
            result = True
            break
            
    return result

# %%
import ConfigParser

Config = ConfigParser.ConfigParser()
Config.read("./config.ini")

def ConfigSectionMap(section):
    dict1 = {}
    options = Config.options(section)
    print options
    for option in options:
        try:
            dict1[option] = Config.get(section, option)
            if dict1[option] == -1:
                DebugPrint("skip: %s" % option)
        except:
            print("exception on %s!" % option)
            dict1[option] = None
    return dict1


from slackclient import SlackClient
import io
slack_token = ConfigSectionMap("Slack")['secrettoken']
channel_id = ConfigSectionMap("Slack")['channelid']
sc = SlackClient(slack_token)


def notifySlack(plt, image_np):
    plt.imsave("/data/plot.png", image_np)
            
    sc.api_call(
      "chat.postMessage",
      channel=channel_id,
      text="Unidentified person detected in kitchen for file={}".format(file)

    )


    with open('/data/plot.png', 'rb') as f:
        sc.api_call(
            "files.upload",
            channels=channel_id,
            filename='snapshot.png',
            title='Detected Person',
            initial_comment='Detected person by webcam. Is it anyone you know?',
            file=io.BytesIO(f.read())
        )

    with open(file, 'rb') as f:
        sc.api_call(
            "files.upload",
            channels=channel_id,
            filename='$file',
            title='Video with detected person',
            initial_comment='Video with detected person',
            file=io.BytesIO(f.read())
        )
# Out:
# ['secrettoken', 'channelid']
# ['secrettoken', 'channelid']

# %%
FRAMES_TO_SKIP = 5

def processVideoFile(file):
     cap = cv2.VideoCapture(file)
     totalFrameCount = cap.get(cv2.cv.CV_CAP_PROP_FRAME_COUNT)
    
     if totalFrameCount == 0:
            print "Video file={} not yet ready for processing. Skipping.".format(file)
            return False
        
     print "Processing video file with {} frames".format( totalFrameCount)
     
     while True:
        ret, image_np = cap.read()
        currentFrame = cap.get(cv2.cv.CV_CAP_PROP_POS_FRAMES)
        print "Processing frame {} of {} for video file={}".format(currentFrame,totalFrameCount, file) 
        if not ret:
            break
       
         # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
        image_np_expanded = np.expand_dims(image_np, axis=0)
         # Actual detection.
        output_dict = run_inference_for_single_image(image_np, detection_graph)
        # Visualization of the results of a detection.
         


        if detectPerson(output_dict,category_index):
            print "detected person"
            vis_util.visualize_boxes_and_labels_on_image_array(
              image_np,
              output_dict['detection_boxes'],
              output_dict['detection_classes'],
              output_dict['detection_scores'],
              category_index,
              instance_masks=output_dict.get('detection_masks'),
              use_normalized_coordinates=True,
              line_thickness=8)
            #plt.figure(figsize=IMAGE_SIZE)
            #plt.imshow(image_np)
            notifySlack(plt, image_np)
            
            break
            
        # skips frames as the rate of the camera is 20 fps
        nextFrame = min(currentFrame + FRAMES_TO_SKIP, totalFrameCount)
        cap.set(cv2.cv.CV_CAP_PROP_POS_FRAMES, nextFrame)  
     return True

# %%
while True:

  file = wait_for_video( "/data/videos/incoming", 3600 * 354, 1 ) 

  if file is None:
    break
  
  result = processVideoFile(file)
  
  if result:
        moveVideoToArchive(file)
# Out:
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Processing video file with 181.0 frames
# Processing frame 1.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 7.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 13.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 19.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 25.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 31.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 37.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 43.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 49.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 55.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 61.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 67.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 73.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 79.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 85.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 91.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 97.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 103.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 109.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 115.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 121.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# Processing frame 127.0 of 181.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180502_224814.mp4
# detected person
# Searching for new camera uploads
# Processing video file with 169.0 frames
# Processing frame 1.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 7.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 13.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 19.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 25.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 31.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 37.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 43.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 49.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 55.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 61.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 67.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 73.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 79.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 85.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 91.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 97.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 103.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 109.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 115.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 121.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 127.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 133.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 139.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 145.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 151.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 157.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 163.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 169.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Processing frame 169.0 of 169.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044620.mp4
# Searching for new camera uploads
# Processing video file with 194.0 frames
# Processing frame 1.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 7.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 13.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 19.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 25.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 31.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 37.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 43.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 49.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 55.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 61.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 67.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 73.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 79.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 85.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 91.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 97.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 103.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 109.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 115.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 121.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 127.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 133.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 139.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 145.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 151.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 157.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 163.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 169.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 175.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 181.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 187.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 193.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Processing frame 194.0 of 194.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_053345.mp4
# Searching for new camera uploads
# Processing video file with 184.0 frames
# Processing frame 1.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 7.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 13.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 19.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 25.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 31.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 37.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 43.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 49.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 55.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 61.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 67.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 73.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 79.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 85.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 91.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 97.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 103.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 109.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 115.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 121.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 127.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 133.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 139.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 145.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 151.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 157.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 163.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 169.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 175.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 181.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Processing frame 184.0 of 184.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_044049.mp4
# Searching for new camera uploads
# Processing video file with 201.0 frames
# Processing frame 1.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 7.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 13.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 19.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 25.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 31.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 37.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 43.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 49.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 55.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 61.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 67.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 73.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 79.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 85.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 91.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 97.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 103.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 109.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 115.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 121.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 127.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 133.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 139.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 145.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 151.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 157.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 163.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 169.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 175.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 181.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 187.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 193.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 199.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Processing frame 201.0 of 201.0 for video file=/data/videos/incoming/random_folder3/VID_20180509_045556.mp4
# Searching for new camera uploads
# Processing video file with 165.0 frames
# Processing frame 1.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 7.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 13.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 19.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 25.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 31.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 37.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 43.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 49.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 55.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 61.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 67.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 73.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 79.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 85.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 91.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 97.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 103.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 109.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 115.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 121.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 127.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 133.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 139.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 145.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 151.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 157.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 163.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Processing frame 165.0 of 165.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180508_045225.mp4
# Searching for new camera uploads
# Processing video file with 217.0 frames
# Processing frame 1.0 of 217.0 for video file=/data/videos/incoming/random_folder1/random_folder2/VID_20180425_213032.mp4
# detected person
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
# Searching for new camera uploads
